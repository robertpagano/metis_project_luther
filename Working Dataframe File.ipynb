# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import seaborn as sns

# %%
rays_df = pd.read_csv("rays 2018.csv")
data.head(5)
# Out:
#    Gm#             Date Unnamed: 2   Tm Unnamed: 4  Opp W/L  R  RA  Inn  \
# 0    1  Thursday Mar 29   boxscore  TBR        NaN  BOS   W  6   4  NaN
# 1    2    Friday Mar 30   boxscore  TBR        NaN  BOS   L  0   1  NaN
# 2    3  Saturday Mar 31   boxscore  TBR        NaN  BOS   L  2   3  NaN
# 3    4     Sunday Apr 1   boxscore  TBR        NaN  BOS   L  1   2  NaN
# 4    5    Tuesday Apr 3   boxscore  TBR          @  NYY   L  4  11  NaN
#
#         ...       Rank    GB        Win       Loss     Save  Time D/N  \
# 0       ...          1  Tied     Pruitt      Smith   Colome  3:00   D
# 1       ...          3   1.0      Price        Roe  Kimbrel  2:46   N
# 2       ...          4   1.0   Porcello  Kittredge  Kimbrel  3:21   N
# 3       ...          5   2.0  Velazquez   Alvarado    Kelly  3:24   D
# 4       ...          4   3.5     Kahnle     Pruitt      NaN  3:29   D
#
#   Attendance  Streak Orig. Scheduled
# 0    31042.0       +             NaN
# ...

# %%
rays_df.columns
# Out:
# Index(['Gm#', 'Date', 'Unnamed: 2', 'Tm', 'Unnamed: 4', 'Opp', 'W/L', 'R',
#        'RA', 'Inn', 'W-L', 'Rank', 'GB', 'Win', 'Loss', 'Save', 'Time', 'D/N',
#        'Attendance', 'Streak', 'Orig. Scheduled'],
#       dtype='object')

# %%
rays_df.rename(columns={'Unnamed: 4': 'is away', 'R': 'Runs scored', 'RA': 'Runs allowed'}, inplace=True)
rays_df.columns
# Out:
# Index(['Gm#', 'Date', 'Unnamed: 2', 'Tm', 'is away', 'Opp', 'W/L',
#        'Runs scored', 'Runs allowed', 'Inn', 'W-L', 'Rank', 'GB', 'Win',
#        'Loss', 'Save', 'Time', 'D/N', 'Attendance', 'Streak',
#        'Orig. Scheduled'],
#       dtype='object')

# %%
cols_to_keep = ['Gm#', 'Date', 'Tm', 'is away', 'Opp', 'W/L', 'Runs scored', 'Runs allowed', 'W-L', 'Rank', 'GB', 'Time', 'D/N', 'Attendance', 'Streak']

# def clean_team_data(data):
#     df.drop('U')

# %%
cleaned_rays_df = rays_df[cols_to_keep]
cleaned_rays_df
# Out:
#      Gm#              Date   Tm is away  Opp   W/L  Runs scored  Runs allowed  \
# 0      1   Thursday Mar 29  TBR     NaN  BOS     W            6             4
# 1      2     Friday Mar 30  TBR     NaN  BOS     L            0             1
# 2      3   Saturday Mar 31  TBR     NaN  BOS     L            2             3
# 3      4      Sunday Apr 1  TBR     NaN  BOS     L            1             2
# 4      5     Tuesday Apr 3  TBR       @  NYY     L            4            11
# 5      6   Wednesday Apr 4  TBR       @  NYY     L            2             7
# 6      7    Thursday Apr 5  TBR       @  BOS  L-wo            2             3
# 7      8    Saturday Apr 7  TBR       @  BOS     L            3            10
# 8      9      Sunday Apr 8  TBR       @  BOS     L            7             8
# 9     10      Monday Apr 9  TBR       @  CHW     W            5             4
# 10    11    Tuesday Apr 10  TBR       @  CHW     W            6             5
# ...
