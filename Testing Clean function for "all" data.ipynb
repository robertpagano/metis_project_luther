# %%
import numpy as np
import pandas as pd
import data_clean_functions as dcf
import os
import pickle

# %%
with open('/Users/robertpagano/src/metis_project_luther/data/merged_data_2014_2018_final_uncleaned.pickle', "rb") as to_read:
    df = pickle.load(to_read)

# %%
df.tail()
# Out:
#        Gm#       Date             Tm Location  Opp W/L   R  RA Inn   ...     \
# 24291  158  201809250  boxscore  WSN           MIA   W   9   4       ...
# 24292  159  201809260  boxscore  WSN           MIA   W   9   3   7   ...
# 24293  160  201809280  boxscore  WSN        @  COL   L   2   5       ...
# 24294  161  201809290  boxscore  WSN        @  COL   W  12   2       ...
# 24295  162  201809300  boxscore  WSN        @  COL   L   0  12       ...
#
#          GB        Win     Loss   Save  Time D/N Attendance Streak  \
# 24291   9.5   Scherzer  Brigham         3:12   N     26,483     ++
# 24292   8.5      Suero     Chen         2:45   D     28,680    +++
# 24293   9.0   Freeland     Ross  Davis  2:51   N     48,089      -
# 24294   8.0  Strasburg     Gray         3:40   N     47,781      +
# 24295   8.0   Anderson    Fedde         3:02   D     47,833      -
#
#       Orig. Scheduled HomeGame
# 24291                     True
# 24292                     True
# 24293                    False
# 24294                    False
# 24295                    False
#
# [5 rows x 22 columns]

# %%
dcf.clean_team(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-21809656a438> in <module>
# ----> 1 dcf.clean_team(df)
#
# ~/src/metis_project_luther/data_clean_functions.py in clean_team(df)
#     134 def clean_team(df):
#     135         df = rename_columns(df)
# --> 136         df = filter_columns(df)
#     137         df = clean_night_game(df)
#     138         df = clean_GB_col(df)
#
# ~/src/metis_project_luther/data_clean_functions.py in filter_columns(df)
#      17         cols_to_keep = ['Attendance', 'Gm#', 'Date', 'Tm', 'is_home', 'Opp', 'W/L', 'runs_scored', 'runs_allowed', 'W-L', 'Rank', 'GB', 'Time', 'is_night', 'Streak']
#      18         # return df[[cols_to_keep]]
# ---> 19         df.drop(['Win', 'Loss', 'Save', 'Inn', 'Orig. Scheduled'], axis=1, inplace = True)
#      20         df = df[cols_to_keep]
#      21         return df
#
# AttributeError: 'NoneType' object has no attribute 'drop'
