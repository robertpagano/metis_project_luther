# %%
import numpy as np
import pandas as pd
import data_clean_functions as dcf
import os
import pickle

# %%
with open('/Users/robertpagano/src/metis_project_luther/data/merged_data_2014_2018_final_uncleaned.pickle', "rb") as to_read:
    df = pickle.load(to_read)

# %%
df.head()
# Out:
#   Gm#       Date             Tm Location  Opp W/L  runs_scored  runs_allowed  \
# 0   1  201403310  boxscore  ATL        @  MIL   L            0             2
# 1   2  201404010  boxscore  ATL        @  MIL   W            5             2
# 2   3  201404020  boxscore  ATL        @  MIL   W            1             0
# 3   4  201404040  boxscore  ATL        @  WSN   W            2             1
# 4   5  201404050  boxscore  ATL        @  WSN   W            6             2
#
#   Inn ... cum_runs_allowed run_differential  Win_differential win_value  \
# 0     ...                2               -2                -1         0
# 1     ...                4                1                 0         1
# 2     ...                4                2                 1         1
# 3     ...                5                3                 2         1
# 4     ...                7                7                 3         1
#
#   Wins_last_10 Mean_runs_last_10 date_fixed  year  month day
# 0          NaN               0.0   20140331  2014     03  31
# 1          NaN               2.5   20140401  2014     04  01
# 2          NaN               2.0   20140402  2014     04  02
# 3          NaN               2.0   20140404  2014     04  04
# 4          NaN               2.8   20140405  2014     04  05
#
# [5 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['Gm#', 'Date', '', 'Tm', 'Location', 'Opp', 'W/L', 'runs_scored',
#        'runs_allowed', 'Inn', 'W-L', 'Rank', 'GB', 'Win', 'Loss', 'Save',
#        'Time', 'is_night', 'Attendance', 'Streak', 'Orig. Scheduled',
#        'is_home', 'Total_wins', 'Total_losses', 'cum_runs_scored',
#        'cum_runs_allowed', 'run_differential', 'Win_differential', 'win_value',
#        'Wins_last_10', 'Mean_runs_last_10', 'date_fixed', 'year', 'month',
#        'day'],
#       dtype='object')

# %%
df = df[['Attendance', 'Gm#', 'Date', 'Tm', 'Opp', 'W/L', 'runs_scored', 'runs_allowed', 'W-L', 'Rank', 'GB', 'Time', 'is_night', 'Streak', 'is_home', 'Total_wins', 'Total_losses', 'cum_runs_scored', 'cum_runs_allowed', 'run_differential', 'Win_differential', 'win_value', 'Wins_last_10', 'Mean_runs_last_10', 'date_fixed', 'year', 'month', 'day']]
df.columns
# Out:
# Index(['Attendance', 'Gm#', 'Date', 'Tm', 'Opp', 'W/L', 'runs_scored',
#        'runs_allowed', 'W-L', 'Rank', 'GB', 'Time', 'is_night', 'Streak',
#        'is_home', 'Total_wins', 'Total_losses', 'cum_runs_scored',
#        'cum_runs_allowed', 'run_differential', 'Win_differential', 'win_value',
#        'Wins_last_10', 'Mean_runs_last_10', 'date_fixed', 'year', 'month',
#        'day'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24296 entries, 0 to 24295
# Data columns (total 28 columns):
# Attendance           24196 non-null float64
# Gm#                  24296 non-null object
# Date                 24296 non-null object
# Tm                   24296 non-null object
# Opp                  24296 non-null object
# W/L                  24296 non-null object
# runs_scored          24296 non-null int64
# runs_allowed         24296 non-null int64
# W-L                  24296 non-null object
# Rank                 24296 non-null object
# GB                   24296 non-null float64
# Time                 24296 non-null object
# is_night             24296 non-null int64
# Streak               24296 non-null object
# is_home              24296 non-null int64
# Total_wins           24296 non-null int64
# Total_losses         24296 non-null int64
# cum_runs_scored      24296 non-null int64
# cum_runs_allowed     24296 non-null int64
# run_differential     24296 non-null int64
# Win_differential     24296 non-null int64
# win_value            24296 non-null int64
# Wins_last_10         22946 non-null float64
# Mean_runs_last_10    24296 non-null float64
# date_fixed           24296 non-null int64
# year                 24296 non-null object
# month                24296 non-null object
# day                  24296 non-null object
# dtypes: float64(4), int64(12), object(12)
# memory usage: 5.4+ MB

# %%
df['Gm#'] = df['Gm#'].apply(pd.to_numeric)

# %%
df.sample(5)
# Out:
#        Attendance  Gm#       Date   Tm  Opp W/L  runs_scored  runs_allowed  \
# 7646      31496.0   35  201505140  NYM  CHC   L            5             6
# 19723     43867.0  128  201808240  ARI  SEA   L            3             6
# 24084     36798.0  113  201808080  TOR  BOS   L            5            10
# 17365     17471.0   38  201705160  NYM  ARI   L            4             5
# 22637     32204.0  123  201808180  OAK  HOU   W            7             1
#
#          W-L Rank ...   cum_runs_allowed run_differential  Win_differential  \
# 7646   20-15    1 ...                113               17                 5
# 19723  71-57    1 ...                496               83                14
# 24084  51-62    4 ...                578              -67               -11
# 17365  16-22    2 ...                215              -24                -6
# 22637  74-49    1 ...                510               72                25
#
#       win_value  Wins_last_10  Mean_runs_last_10  date_fixed  year  month  day
# 7646          0           4.0                2.9    20150514  2015     05   14
# 19723         0           7.0                5.5    20180824  2018     08   24
# 24084         0           4.0                4.7    20180808  2018     08   08
# 17365         0           3.0                5.0    20170516  2017     05   16
# 22637         1           7.0                4.4    20180818  2018     08   18
#
# [5 rows x 28 columns]

# %%
with open('merged_data_initial_clean_V2.pickle', 'wb') as to_write:
    pickle.dump(df, to_write)

# %% [markdown]
# Now what I am planning to do, filter down for just the features I want in initial analysis, and then pull in the OPP features for the same. I.e. there will be an opp GB, win_differential, etc.

# %% [markdown]
# Below I'm going to do some more feature engineering:
#  - Opponent values
#  - payroll (plus opponent payroll)
#  - day of week
#  - Batter age
#  - all-stars

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24296 entries, 0 to 24295
# Data columns (total 28 columns):
# Attendance           24196 non-null float64
# Gm#                  24296 non-null int64
# Date                 24296 non-null object
# Tm                   24296 non-null object
# Opp                  24296 non-null object
# W/L                  24296 non-null object
# runs_scored          24296 non-null int64
# runs_allowed         24296 non-null int64
# W-L                  24296 non-null object
# Rank                 24296 non-null object
# GB                   24296 non-null float64
# Time                 24296 non-null object
# is_night             24296 non-null int64
# Streak               24296 non-null object
# is_home              24296 non-null int64
# Total_wins           24296 non-null int64
# Total_losses         24296 non-null int64
# cum_runs_scored      24296 non-null int64
# cum_runs_allowed     24296 non-null int64
# run_differential     24296 non-null int64
# Win_differential     24296 non-null int64
# win_value            24296 non-null int64
# Wins_last_10         22946 non-null float64
# Mean_runs_last_10    24296 non-null float64
# date_fixed           24296 non-null int64
# year                 24296 non-null object
# month                24296 non-null object
# day                  24296 non-null object
# dtypes: float64(4), int64(13), object(11)
# memory usage: 5.4+ MB

# %%
df['Tm_Date'] = df['Tm'] + df.date_fixed.map(str)
df['Opp_Date'] = df['Opp'] + df.date_fixed.map(str)

df.head()
# Out:
#    Attendance  Gm#       Date   Tm  Opp W/L  runs_scored  runs_allowed  W-L  \
# 0     45691.0    1  201403310  ATL  MIL   L            0             2  0-1
# 1     21503.0    2  201404010  ATL  MIL   W            5             2  1-1
# 2     21712.0    3  201404020  ATL  MIL   W            1             0  2-1
# 3     42834.0    4  201404040  ATL  WSN   W            2             1  3-1
# 4     37841.0    5  201404050  ATL  WSN   W            6             2  4-1
#
#   Rank     ...       Win_differential win_value  Wins_last_10  \
# 0    4     ...                     -1         0           NaN
# 1    3     ...                      0         1           NaN
# 2    2     ...                      1         1           NaN
# 3    2     ...                      2         1           NaN
# 4    2     ...                      3         1           NaN
#
#   Mean_runs_last_10  date_fixed  year  month  day      Tm_Date     Opp_Date
# 0               0.0    20140331  2014     03   31  ATL20140331  MIL20140331
# 1               2.5    20140401  2014     04   01  ATL20140401  MIL20140401
# 2               2.0    20140402  2014     04   02  ATL20140402  MIL20140402
# 3               2.0    20140404  2014     04   04  ATL20140404  WSN20140404
# 4               2.8    20140405  2014     04   05  ATL20140405  WSN20140405
#
# [5 rows x 30 columns]

# %% [markdown]
# Below I am using merge function to pull in opponent values

# %%
df['Rank'] = df['Rank'].apply(pd.to_numeric)
df.head()
# Out:
#    Attendance  Gm#       Date   Tm  Opp W/L  runs_scored  runs_allowed  W-L  \
# 0     45691.0    1  201403310  ATL  MIL   L            0             2  0-1
# 1     21503.0    2  201404010  ATL  MIL   W            5             2  1-1
# 2     21712.0    3  201404020  ATL  MIL   W            1             0  2-1
# 3     42834.0    4  201404040  ATL  WSN   W            2             1  3-1
# 4     37841.0    5  201404050  ATL  WSN   W            6             2  4-1
#
#    Rank     ...       Win_differential win_value  Wins_last_10  \
# 0     4     ...                     -1         0           NaN
# 1     3     ...                      0         1           NaN
# 2     2     ...                      1         1           NaN
# 3     2     ...                      2         1           NaN
# 4     2     ...                      3         1           NaN
#
#   Mean_runs_last_10  date_fixed  year  month  day      Tm_Date     Opp_Date
# 0               0.0    20140331  2014     03   31  ATL20140331  MIL20140331
# 1               2.5    20140401  2014     04   01  ATL20140401  MIL20140401
# 2               2.0    20140402  2014     04   02  ATL20140402  MIL20140402
# 3               2.0    20140404  2014     04   04  ATL20140404  WSN20140404
# 4               2.8    20140405  2014     04   05  ATL20140405  WSN20140405
#
# [5 rows x 30 columns]

# %%
df['team_year'] = df['Tm'] + df['year']
df.head()
# Out:
#    Attendance  Gm#       Date   Tm  Opp W/L  runs_scored  runs_allowed  W-L  \
# 0     45691.0    1  201403310  ATL  MIL   L            0             2  0-1
# 1     21503.0    2  201404010  ATL  MIL   W            5             2  1-1
# 2     21712.0    3  201404020  ATL  MIL   W            1             0  2-1
# 3     42834.0    4  201404040  ATL  WSN   W            2             1  3-1
# 4     37841.0    5  201404050  ATL  WSN   W            6             2  4-1
#
#    Rank    ...      win_value Wins_last_10  Mean_runs_last_10 date_fixed  \
# 0     4    ...              0          NaN                0.0   20140331
# 1     3    ...              1          NaN                2.5   20140401
# 2     2    ...              1          NaN                2.0   20140402
# 3     2    ...              1          NaN                2.0   20140404
# 4     2    ...              1          NaN                2.8   20140405
#
#    year  month  day      Tm_Date     Opp_Date  team_year
# 0  2014     03   31  ATL20140331  MIL20140331    ATL2014
# 1  2014     04   01  ATL20140401  MIL20140401    ATL2014
# 2  2014     04   02  ATL20140402  MIL20140402    ATL2014
# 3  2014     04   04  ATL20140404  WSN20140404    ATL2014
# 4  2014     04   05  ATL20140405  WSN20140405    ATL2014
#
# [5 rows x 31 columns]

# %%
team_salaries = pd.read_csv('/Users/robertpagano/src/metis_project_luther/Data/team_salary.csv', delimiter=',')
team_salaries.tail(30)
# Out:
#     team_year  batter_age  current_all_stars  lifetime_all_stars  \
# 120   ARI2014        27.6                  2                  13
# 121   ATL2014        26.8                  3                   9
# 122   BAL2014        28.3                  3                  16
# 123   BOS2014        29.2                  2                  21
# 124   CHC2014        26.8                  3                   7
# 125   CHW2014        27.7                  3                   7
# 126   CIN2014        29.0                  5                  11
# 127   CLE2014        28.6                  1                  13
# 128   COL2014        27.4                  2                   9
# 129   DET2014        29.8                  4                  16
# 130   HOU2014        25.4                  1                   6
# 131   KCR2014        28.2                  3                  15
# 132   LAA2014        29.3                  2                  13
# 133   LAD2014        29.3                  4                  20
# 134   MIA2014        27.4                  2                  12
# 135   MIL2014        28.8                  4                  14
# 136   MIN2014        27.5                  2                   8
# 137   NYM2014        28.4                  1                   9
# 138   NYY2014        32.8                  3                  18
# 139   OAK2014        29.6                  6                  16
# 140   PHI2014        30.8                  1                  12
# 141   PIT2014        27.3                  3                  14
# 142   SDP2014        27.9                  2                   6
# 143   SEA2014        27.5                  4                  10
# 144   SFG2014        28.6                  3                  16
# 145   STL2014        28.6                  4                  15
# 146   TBR2014        29.3                  1                  11
# 147   TEX2014        28.4                  2                  15
# 148   TOR2014        29.2                  3                  12
# 149   WSN2014        28.8                  2                  14
#
#      player_salary
# 120       89926500
# 121      108081500
# 122      109097500
# 123      134628929
# 124       59800500
# 125       87475500
# 126      102230000
# 127       73509399
# 128       95403500
# 129      169135500
# 130       44736800
# 131       89804075
# 132      128667000
# 133      233386026
# 134       42365400
# 135      109567000
# 136       87044000
# 137       82663615
# 138      258118959
# 139       89160900
# 140      176444967
# 141       80729000
# 142       76662100
# 143       95471000
# 144      163510167
# 145      129932500
# 146       77814300
# 147      129801239
# 148      136466200
# 149      137235080

# %%
df = pd.merge(df, team_salaries, how='left', left_on='team_year', right_on='team_year')
df.head()
# Out:
#    Attendance  Gm#       Date   Tm  Opp W/L  runs_scored  runs_allowed  W-L  \
# 0     45691.0    1  201403310  ATL  MIL   L            0             2  0-1
# 1     21503.0    2  201404010  ATL  MIL   W            5             2  1-1
# 2     21712.0    3  201404020  ATL  MIL   W            1             0  2-1
# 3     42834.0    4  201404040  ATL  WSN   W            2             1  3-1
# 4     37841.0    5  201404050  ATL  WSN   W            6             2  4-1
#
#    Rank      ...        year month  day      Tm_Date     Opp_Date  team_year  \
# 0     4      ...        2014    03   31  ATL20140331  MIL20140331    ATL2014
# 1     3      ...        2014    04   01  ATL20140401  MIL20140401    ATL2014
# 2     2      ...        2014    04   02  ATL20140402  MIL20140402    ATL2014
# 3     2      ...        2014    04   04  ATL20140404  WSN20140404    ATL2014
# 4     2      ...        2014    04   05  ATL20140405  WSN20140405    ATL2014
#
#    batter_age  current_all_stars  lifetime_all_stars  player_salary
# 0        26.8                  3                   9      108081500
# 1        26.8                  3                   9      108081500
# 2        26.8                  3                   9      108081500
# 3        26.8                  3                   9      108081500
# 4        26.8                  3                   9      108081500
#
# [5 rows x 35 columns]

# %%
df_opp = df.copy()

# %% [markdown]
# Here I am creating another dataframe to prepare to merge the "opp" data with the main dataframe.

# %%
df_opp = df_opp[['Tm_Date', 'Wins_last_10', 'Win_differential', 'Rank', 'GB', 'Mean_runs_last_10', 'batter_age', 'current_all_stars', 'lifetime_all_stars', 'player_salary']]
df_opp.head()
# Out:
#        Tm_Date  Wins_last_10  Win_differential  Rank   GB  Mean_runs_last_10  \
# 0  ATL20140331           NaN                -1     4  1.0                0.0
# 1  ATL20140401           NaN                 0     3  1.0                2.5
# 2  ATL20140402           NaN                 1     2  0.5                2.0
# 3  ATL20140404           NaN                 2     2  0.5                2.0
# 4  ATL20140405           NaN                 3     2  0.5                2.8
#
#    batter_age  current_all_stars  lifetime_all_stars  player_salary
# 0        26.8                  3                   9      108081500
# 1        26.8                  3                   9      108081500
# 2        26.8                  3                   9      108081500
# 3        26.8                  3                   9      108081500
# 4        26.8                  3                   9      108081500

# %%
df_opp.rename(columns = {'Tm_Date': 'Opp_Date', 'Wins_last_10': 'Opp_Wins_last_10', 'Win_differential': 'Opp_Win_differential', 'Rank': 'Opp_Rank', 'GB': 'Opp_GB', 'Mean_runs_last_10': 'Opp_Mean_runs_last_10', 'batter_age': 'opp_batter_age', 'current_all_stars': 'opp_current_all_stars', 'lifetime_all_stars': 'opp_lifetime_all_stars', 'player_salary': 'opp_player_salary'}, inplace=True)
df_opp.head()
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#       Opp_Date  Opp_Wins_last_10  Opp_Win_differential  Opp_Rank  Opp_GB  \
# 0  ATL20140331               NaN                    -1         4     1.0
# 1  ATL20140401               NaN                     0         3     1.0
# 2  ATL20140402               NaN                     1         2     0.5
# 3  ATL20140404               NaN                     2         2     0.5
# 4  ATL20140405               NaN                     3         2     0.5
#
#    Opp_Mean_runs_last_10  opp_batter_age  opp_current_all_stars  \
# 0                    0.0            26.8                      3
# 1                    2.5            26.8                      3
# 2                    2.0            26.8                      3
# 3                    2.0            26.8                      3
# 4                    2.8            26.8                      3
#
#    opp_lifetime_all_stars  opp_player_salary
# 0                       9          108081500
# 1                       9          108081500
# 2                       9          108081500
# 3                       9          108081500
# 4                       9          108081500

# %%
print(df.shape)
print(df_opp.shape)
# Out:
# (24296, 35)
# (24296, 10)

# %%
df = pd.merge(df, df_opp, how='left', left_on='Opp_Date', right_on='Opp_Date')
df.head()
# Out:
#    Attendance  Gm#       Date   Tm  Opp W/L  runs_scored  runs_allowed  W-L  \
# 0     45691.0    1  201403310  ATL  MIL   L            0             2  0-1
# 1     21503.0    2  201404010  ATL  MIL   W            5             2  1-1
# 2     21712.0    3  201404020  ATL  MIL   W            1             0  2-1
# 3     42834.0    4  201404040  ATL  WSN   W            2             1  3-1
# 4     37841.0    5  201404050  ATL  WSN   W            6             2  4-1
#
#    Rank        ...          player_salary Opp_Wins_last_10  \
# 0     4        ...              108081500              NaN
# 1     3        ...              108081500              NaN
# 2     2        ...              108081500              NaN
# 3     2        ...              108081500              NaN
# 4     2        ...              108081500              NaN
#
#    Opp_Win_differential Opp_Rank  Opp_GB  Opp_Mean_runs_last_10  \
# 0                     1        1     0.0               2.000000
# 1                     0        3     0.5               2.000000
# 2                    -1        4     1.5               1.333333
# 3                     2        2     0.5               5.750000
# 4                     1        3     1.5               5.000000
#
#    opp_batter_age  opp_current_all_stars  opp_lifetime_all_stars  \
# 0            28.8                      4                      14
# 1            28.8                      4                      14
# 2            28.8                      4                      14
# 3            28.8                      2                      14
# 4            28.8                      2                      14
#
#    opp_player_salary
# 0          109567000
# 1          109567000
# 2          109567000
# 3          137235080
# 4          137235080
#
# [5 rows x 44 columns]

# %% [markdown]
# This worked! So now I have opposing team data.
#
# Below, I want to decide when to cut off the weekend calculation, so I'll plot some data for attendance by day of week. First I will add day of week, then plot it:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['date_fixed'] = df['date_fixed'].apply(str)

# %%
df['weekday'] = df['datetime'].dt.dayofweek
df.head()
# Out:
#    Attendance  Gm#       Date   Tm  Opp W/L  runs_scored  runs_allowed  W-L  \
# 0     45691.0    1  201403310  ATL  MIL   L            0             2  0-1
# 1     21503.0    2  201404010  ATL  MIL   W            5             2  1-1
# 2     21712.0    3  201404020  ATL  MIL   W            1             0  2-1
# 3     42834.0    4  201404040  ATL  WSN   W            2             1  3-1
# 4     37841.0    5  201404050  ATL  WSN   W            6             2  4-1
#
#    Rank   ...     Opp_Win_differential Opp_Rank  Opp_GB Opp_Mean_runs_last_10  \
# 0     4   ...                        1        1     0.0              2.000000
# 1     3   ...                        0        3     0.5              2.000000
# 2     2   ...                       -1        4     1.5              1.333333
# 3     2   ...                        2        2     0.5              5.750000
# 4     2   ...                        1        3     1.5              5.000000
#
#    opp_batter_age  opp_current_all_stars  opp_lifetime_all_stars  \
# 0            28.8                      4                      14
# 1            28.8                      4                      14
# 2            28.8                      4                      14
# 3            28.8                      2                      14
# 4            28.8                      2                      14
#
#    opp_player_salary   datetime  weekday
# 0          109567000 2014-03-31        0
# 1          109567000 2014-04-01        1
# 2          109567000 2014-04-02        2
# 3          137235080 2014-04-04        4
# 4          137235080 2014-04-05        5
#
# [5 rows x 46 columns]

# %%
import datetime as dt
df['weekday'] = df[['datetime']].apply(lambda x: dt.datetime.strftime(x['datetime'], '%A'), axis=1)
df.head()
# Out:
#    Attendance  Gm#       Date   Tm  Opp W/L  runs_scored  runs_allowed  W-L  \
# 0     45691.0    1  201403310  ATL  MIL   L            0             2  0-1
# 1     21503.0    2  201404010  ATL  MIL   W            5             2  1-1
# 2     21712.0    3  201404020  ATL  MIL   W            1             0  2-1
# 3     42834.0    4  201404040  ATL  WSN   W            2             1  3-1
# 4     37841.0    5  201404050  ATL  WSN   W            6             2  4-1
#
#    Rank    ...      Opp_Win_differential Opp_Rank  Opp_GB  \
# 0     4    ...                         1        1     0.0
# 1     3    ...                         0        3     0.5
# 2     2    ...                        -1        4     1.5
# 3     2    ...                         2        2     0.5
# 4     2    ...                         1        3     1.5
#
#   Opp_Mean_runs_last_10  opp_batter_age  opp_current_all_stars  \
# 0              2.000000            28.8                      4
# 1              2.000000            28.8                      4
# 2              1.333333            28.8                      4
# 3              5.750000            28.8                      2
# 4              5.000000            28.8                      2
#
#    opp_lifetime_all_stars  opp_player_salary   datetime    weekday
# 0                      14          109567000 2014-03-31     Monday
# 1                      14          109567000 2014-04-01    Tuesday
# 2                      14          109567000 2014-04-02  Wednesday
# 3                      14          137235080 2014-04-04     Friday
# 4                      14          137235080 2014-04-05   Saturday
#
# [5 rows x 46 columns]

# %%
weekday_plot = sns.barplot(x = 'weekday', y='Attendance', 
            data=df, 
            order=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'], 
            ci = None, 
            palette = ['grey', 'grey', 'grey', 'grey', 'deepskyblue', 'deepskyblue', 'deepskyblue'], 
            saturation = .4);

for item in weekday_plot.get_xticklabels():
    item.set_rotation(45)

weekday_plot.set(xlabel='', ylabel='Average Attendance', title='Attendance by Day of Week')
plt.show()

# %% [markdown]
# Below I am creating the "is_weekend" variable, including Friday, Saturday, and Sunday

# %%
cols = ['weekday', 'is_weekend']
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
is_weekend_vals = [0,0,0,0,1,1,1]
dvals = list(zip(days,is_weekend_vals))

is_weekday_df = pd.DataFrame(data=dvals, columns=cols)
is_weekday_df
# Out:
#      weekday  is_weekend
# 0     Monday           0
# 1    Tuesday           0
# 2  Wednesday           0
# 3   Thursday           0
# 4     Friday           1
# 5   Saturday           1
# 6     Sunday           1

# %%
df = pd.merge(df, is_weekday_df, how='left', left_on='weekday', right_on='weekday')
df.sample(20)
# Out:
#        Attendance  Gm#       Date   Tm  Opp   W/L  runs_scored  runs_allowed  \
# 12268     17225.0   32  201605100  MIA  MIL     L            2            10
# 12331     18347.0   93  201607190  MIA  PHI     W            2             1
# 2702      41514.0   45  201405230  MIN  SFG     L            2             6
# 24765     11779.0  104  201807280  WSN  MIA  L-wo            1             2
# 14475     32806.0  106  201607310  TEX  KCR     W            5             3
# 3810      17311.0  151  201409170  SDP  PHI     L            2             5
# 8880      46119.0   91  201507180  SEA  NYY     W            4             3
# 8052      38047.0   87  201507110  NYY  BOS     L            3             5
# 15333     28401.0  144  201709110  BAL  TOR     L            3             4
# 2885      34697.0   58  201406030  NYM  CHC  L-wo            1             2
# 7884      40027.0   83  201507050  NYM  LAD     W            8             0
# 11089     38830.0  159  201609290  CIN  STL  L-wo            3             4
# 12783     24668.0   54  201606040  NYM  MIA     W            6             4
# 12084     53409.0   12  201604160  LAD  SFG     L            3             4
# 14325     10793.0  118  201608160  TBR  SDP     W           15             1
# 11460     30304.0   41  201605200  DET  TBR     L            5             7
# 10184     32435.0   78  201606260  ARI  COL  L-wo            7             9
# 18662     39243.0  147  201709150  SDP  COL     L            1             6
# 10407     30855.0  135  201609030  BAL  NYY     W            2             0
# 16333     39243.0  148  201709150  COL  SDP     W            6             1
#
#          W-L  Rank     ...      Opp_Rank Opp_GB  Opp_Mean_runs_last_10  \
# 12268  17-15     4     ...             4   12.0                    6.5
# 12331  51-42     2     ...             4   13.5                    3.4
# 2702   23-22     2     ...             1   -5.0                    4.4
# 24765  52-52     3     ...             4   14.0                    4.1
# 14475  62-44     1     ...             4   12.0                    2.6
# 3810   70-81     3     ...             5   17.5                    3.0
# 8880   42-49     4     ...             1   -3.5                    4.1
# 8052   47-40     1     ...             5    5.5                    5.3
# 15333  71-73     3     ...             5   14.5                    4.5
# 2885   28-30     4     ...             5   12.0                    3.0
# 7884   42-41     2     ...             1   -4.0                    3.6
# 11089  67-92     5     ...             2   18.5                    4.6
# 12783  31-23     2     ...             3    4.0                    3.6
# 12084    7-5     1     ...             1    0.0                    5.5
# 14325  49-69     5     ...             4   16.5                    3.6
# 11460  19-22     4     ...             3    4.5                    6.4
# 10184  36-42     4     ...             3   12.0                    6.3
# 18662  65-82     4     ...             3   14.5                    4.8
# 10407  74-61     3     ...             4    6.5                    5.2
# 16333  81-67     3     ...             4   30.0                    3.0
#
#       opp_batter_age  opp_current_all_stars  opp_lifetime_all_stars  \
# 12268           27.5                      1                       7
# 12331           26.9                      1                       6
# 2702            28.6                      3                      16
# 24765           27.5                      1                       3
# 14475           28.5                      4                      13
# 3810            30.8                      1                      12
# 8880            31.4                      3                      15
# 8052            28.3                      1                      19
# 15333           31.0                      2                      13
# 2885            26.8                      3                       7
# 7884            29.5                      5                      16
# 11089           28.5                      2                      12
# 12783           28.3                      4                      11
# 12084           29.1                      4                      14
# 14325           28.1                      2                      11
# 11460           27.7                      1                       8
# 10184           27.8                      2                       5
# 18662           28.3                      4                       9
# 10407           30.1                      3                      18
# 16333           26.2                      1                       6
#
#        opp_player_salary   datetime    weekday  is_weekend
# 12268           52077500 2016-05-10    Tuesday           0
# 12331           84846666 2016-07-19    Tuesday           0
# 2702           163510167 2014-05-23     Friday           1
# 24765           86515143 2018-07-28   Saturday           1
# 14475          125132675 2016-07-31     Sunday           1
# 3810           176444967 2014-09-17  Wednesday           0
# 8880           214051957 2015-07-18   Saturday           1
# 8052           183931900 2015-07-11   Saturday           1
# 15333          158890575 2017-09-11     Monday           0
# 2885            59800500 2014-06-03    Tuesday           0
# 7884           265140429 2015-07-05     Sunday           1
# 11089          150353500 2016-09-29   Thursday           0
# 12783           72472000 2016-06-04   Saturday           1
# 12084          177021333 2016-04-16   Saturday           1
# 14325           50656166 2016-08-16    Tuesday           0
# 11460           48223791 2016-05-20     Friday           1
# 10184           89707000 2016-06-26     Sunday           1
# 18662          106650000 2017-09-15     Friday           1
# 10407          193229350 2016-09-03   Saturday           1
# 16333           49248767 2017-09-15     Friday           1
#
# [20 rows x 47 columns]

# %%
month_plot = sns.barplot(x = 'month', y='Attendance', 
            data=df,  
            ci = None, 
            color = 'deepskyblue', 
            saturation = .4);

for item in month_plot.get_xticklabels():
    item.set_rotation(45)

month_plot.set(xlabel='', ylabel='Average Attendance', title='Attendance by Month')
plt.show()

# %% [markdown]
# Pickling this df before I:
#  - filter by home
#  - remove non-regression features
#  - remove any rows with null entries for attendance
#  - fill na's in wins last 10 with mean
#
# Once I do the above, it's ready for the regression

# %%
with open('merged_df_added_opp_values_before_reg_filters.pickle', 'wb') as to_write:
    pickle.dump(df, to_write)

# %% [markdown]
# Below I am filtering out away games, then I will pick columns. Same as regression one as before but adding Opp columns

# %%
df_linreg = df[df['is_home'] == 1]
df_linreg.info()
##this is exactly half of the other df, so looks good so far
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12416 entries, 6 to 24828
# Data columns (total 47 columns):
# Attendance                12318 non-null float64
# Gm#                       12416 non-null int64
# Date                      12416 non-null object
# Tm                        12416 non-null object
# Opp                       12416 non-null object
# W/L                       12416 non-null object
# runs_scored               12416 non-null int64
# runs_allowed              12416 non-null int64
# W-L                       12416 non-null object
# Rank                      12416 non-null int64
# GB                        12416 non-null float64
# Time                      12416 non-null object
# is_night                  12416 non-null int64
# Streak                    12416 non-null object
# is_home                   12416 non-null int64
# Total_wins                12416 non-null int64
# Total_losses              12416 non-null int64
# cum_runs_scored           12416 non-null int64
# cum_runs_allowed          12416 non-null int64
# run_differential          12416 non-null int64
# Win_differential          12416 non-null int64
# win_value                 12416 non-null int64
# Wins_last_10              11735 non-null float64
# Mean_runs_last_10         12416 non-null float64
# date_fixed                12416 non-null object
# year                      12416 non-null object
# month                     12416 non-null object
# day                       12416 non-null object
# Tm_Date                   12416 non-null object
# Opp_Date                  12416 non-null object
# team_year                 12416 non-null object
# batter_age                12416 non-null float64
# current_all_stars         12416 non-null int64
# lifetime_all_stars        12416 non-null int64
# player_salary             12416 non-null int64
# Opp_Wins_last_10          11735 non-null float64
# Opp_Win_differential      12416 non-null int64
# Opp_Rank                  12416 non-null int64
# Opp_GB                    12416 non-null float64
# Opp_Mean_runs_last_10     12416 non-null float64
# opp_batter_age            12416 non-null float64
# opp_current_all_stars     12416 non-null int64
# opp_lifetime_all_stars    12416 non-null int64
# opp_player_salary         12416 non-null int64
# datetime                  12416 non-null datetime64[ns]
# weekday                   12416 non-null object
# is_weekend                12416 non-null int64
# dtypes: datetime64[ns](1), float64(9), int64(22), object(15)
# memory usage: 4.5+ MB

# %%
cols_for_linreg = ['Attendance',
 'Gm#',
 'Rank',
 'GB',
 'is_night',
 'run_differential',
 'Win_differential',
 'Wins_last_10',
 'Mean_runs_last_10',
 'batter_age',
 'current_all_stars',
 'lifetime_all_stars',
 'player_salary',
 'Opp_Wins_last_10',
 'Opp_Win_differential',
 'Opp_Rank',
 'Opp_GB',
 'Opp_Mean_runs_last_10',
 'opp_batter_age',
 'opp_current_all_stars',
 'opp_lifetime_all_stars',
 'opp_player_salary',
 'is_weekend']

##Can pair this down but good to save here

# %%
df_linreg = df_linreg[cols_for_linreg]

df_linreg.head()
df_linreg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12416 entries, 6 to 24828
# Data columns (total 23 columns):
# Attendance                12318 non-null float64
# Gm#                       12416 non-null int64
# Rank                      12416 non-null int64
# GB                        12416 non-null float64
# is_night                  12416 non-null int64
# run_differential          12416 non-null int64
# Win_differential          12416 non-null int64
# Wins_last_10              11735 non-null float64
# Mean_runs_last_10         12416 non-null float64
# batter_age                12416 non-null float64
# current_all_stars         12416 non-null int64
# lifetime_all_stars        12416 non-null int64
# player_salary             12416 non-null int64
# Opp_Wins_last_10          11735 non-null float64
# Opp_Win_differential      12416 non-null int64
# Opp_Rank                  12416 non-null int64
# Opp_GB                    12416 non-null float64
# Opp_Mean_runs_last_10     12416 non-null float64
# opp_batter_age            12416 non-null float64
# opp_current_all_stars     12416 non-null int64
# opp_lifetime_all_stars    12416 non-null int64
# opp_player_salary         12416 non-null int64
# is_weekend                12416 non-null int64
# dtypes: float64(9), int64(14)
# memory usage: 2.3 MB

# %% [markdown]
# Dropping n/a attendance values below:

# %%
df_linreg.dropna(subset=['Attendance'], inplace = True)
df_linreg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12318 entries, 6 to 24828
# Data columns (total 23 columns):
# Attendance                12318 non-null float64
# Gm#                       12318 non-null int64
# Rank                      12318 non-null int64
# GB                        12318 non-null float64
# is_night                  12318 non-null int64
# run_differential          12318 non-null int64
# Win_differential          12318 non-null int64
# Wins_last_10              11639 non-null float64
# Mean_runs_last_10         12318 non-null float64
# batter_age                12318 non-null float64
# current_all_stars         12318 non-null int64
# lifetime_all_stars        12318 non-null int64
# player_salary             12318 non-null int64
# Opp_Wins_last_10          11639 non-null float64
# Opp_Win_differential      12318 non-null int64
# Opp_Rank                  12318 non-null int64
# Opp_GB                    12318 non-null float64
# Opp_Mean_runs_last_10     12318 non-null float64
# opp_batter_age            12318 non-null float64
# opp_current_all_stars     12318 non-null int64
# opp_lifetime_all_stars    12318 non-null int64
# opp_player_salary         12318 non-null int64
# is_weekend                12318 non-null int64
# dtypes: float64(9), int64(14)
# memory usage: 2.3 MB

# %% [markdown]
# Meaning missing wins_last_10 values below:

# %%
df_linreg = df_linreg.fillna(df_linreg.mean())
df_linreg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12318 entries, 6 to 24828
# Data columns (total 23 columns):
# Attendance                12318 non-null float64
# Gm#                       12318 non-null int64
# Rank                      12318 non-null int64
# GB                        12318 non-null float64
# is_night                  12318 non-null int64
# run_differential          12318 non-null int64
# Win_differential          12318 non-null int64
# Wins_last_10              12318 non-null float64
# Mean_runs_last_10         12318 non-null float64
# batter_age                12318 non-null float64
# current_all_stars         12318 non-null int64
# lifetime_all_stars        12318 non-null int64
# player_salary             12318 non-null int64
# Opp_Wins_last_10          12318 non-null float64
# Opp_Win_differential      12318 non-null int64
# Opp_Rank                  12318 non-null int64
# Opp_GB                    12318 non-null float64
# Opp_Mean_runs_last_10     12318 non-null float64
# opp_batter_age            12318 non-null float64
# opp_current_all_stars     12318 non-null int64
# opp_lifetime_all_stars    12318 non-null int64
# opp_player_salary         12318 non-null int64
# is_weekend                12318 non-null int64
# dtypes: float64(9), int64(14)
# memory usage: 2.3 MB

# %%
df_linreg_max_features = df_linreg.copy()

# %%
with open('regression_data_v3_max_features.pickle', 'wb') as to_write:
    pickle.dump(df_linreg_max_features, to_write)

# %%
corr = df_linreg.corr()
corr
# Out:
#                         Attendance       Gm#      Rank        GB  is_night  \
# Attendance                1.000000  0.034016 -0.328797 -0.280089 -0.119577
# Gm#                       0.034016  1.000000  0.030495  0.343676  0.050443
# Rank                     -0.328797  0.030495  1.000000  0.713660  0.010205
# GB                       -0.280089  0.343676  0.713660  1.000000  0.032202
# is_night                 -0.119577  0.050443  0.010205  0.032202  1.000000
# run_differential          0.347011  0.000280 -0.709013 -0.769446 -0.022103
# Win_differential          0.357052  0.003473 -0.772279 -0.830703 -0.014627
# Wins_last_10              0.175483  0.009116 -0.437631 -0.385033 -0.025594
# Mean_runs_last_10         0.090585  0.045391 -0.236625 -0.155026 -0.018387
# batter_age                0.255325  0.006090 -0.170115 -0.151330  0.006022
# current_all_stars         0.319487 -0.001587 -0.537399 -0.520262 -0.009503
# lifetime_all_stars        0.449705  0.001607 -0.379105 -0.375187 -0.008008
# player_salary             0.558339  0.008220 -0.397179 -0.329367  0.000673
# Opp_Wins_last_10         -0.010303 -0.007515  0.128135  0.097876  0.033962
# Opp_Win_differential      0.030410  0.002374  0.117654  0.115094  0.017088
# Opp_Rank                 -0.013288  0.032773 -0.150910 -0.085874 -0.021323
# Opp_GB                   -0.016636  0.345866 -0.099718  0.046972  0.004852
# Opp_Mean_runs_last_10    -0.041793  0.033556  0.122056  0.099352  0.015197
# opp_batter_age            0.005322 -0.007605  0.011231 -0.012238  0.017921
# opp_current_all_stars     0.041622  0.003723  0.074882  0.063899  0.013108
# opp_lifetime_all_stars    0.067223  0.002883  0.036496  0.014794  0.025859
# opp_player_salary         0.053565 -0.006000  0.028398  0.024696  0.020117
# is_weekend                0.285766  0.032328 -0.004624  0.004760 -0.267477
#
#                         run_differential  Win_differential  Wins_last_10  \
# Attendance                      0.347011          0.357052      0.175483
# Gm#                             0.000280          0.003473      0.009116
# Rank                           -0.709013         -0.772279     -0.437631
# GB                             -0.769446         -0.830703     -0.385033
# is_night                       -0.022103         -0.014627     -0.025594
# run_differential                1.000000          0.907203      0.416624
# Win_differential                0.907203          1.000000      0.463211
# Wins_last_10                    0.416624          0.463211      1.000000
# Mean_runs_last_10               0.258948          0.219169      0.498937
# batter_age                      0.124189          0.168324      0.066908
# current_all_stars               0.602602          0.589699      0.265338
# lifetime_all_stars              0.404574          0.411142      0.195955
# player_salary                   0.355715          0.387877      0.176176
# Opp_Wins_last_10               -0.100918         -0.114752     -0.259727
# Opp_Win_differential           -0.097967         -0.112375     -0.120330
# Opp_Rank                        0.094613          0.111708      0.119026
# Opp_GB                          0.108000          0.124021      0.108603
# Opp_Mean_runs_last_10          -0.089329         -0.087142     -0.157563
# opp_batter_age                  0.004860          0.001290     -0.002439
# opp_current_all_stars          -0.068809         -0.061714     -0.063511
# opp_lifetime_all_stars         -0.030909         -0.028611     -0.016638
# opp_player_salary              -0.017396         -0.024576     -0.036168
# is_weekend                      0.006604          0.007219      0.009858
#
#                         Mean_runs_last_10  batter_age     ...      \
# Attendance                       0.090585    0.255325     ...
# Gm#                              0.045391    0.006090     ...
# Rank                            -0.236625   -0.170115     ...
# GB                              -0.155026   -0.151330     ...
# is_night                        -0.018387    0.006022     ...
# run_differential                 0.258948    0.124189     ...
# Win_differential                 0.219169    0.168324     ...
# Wins_last_10                     0.498937    0.066908     ...
# Mean_runs_last_10                1.000000    0.008824     ...
# batter_age                       0.008824    1.000000     ...
# current_all_stars                0.136906    0.186353     ...
# lifetime_all_stars               0.093991    0.407226     ...
# player_salary                    0.141638    0.512946     ...
# Opp_Wins_last_10                -0.126571   -0.007826     ...
# Opp_Win_differential            -0.071116   -0.000386     ...
# Opp_Rank                         0.089416    0.013053     ...
# Opp_GB                           0.092009   -0.003929     ...
# Opp_Mean_runs_last_10            0.047860   -0.022065     ...
# opp_batter_age                  -0.016881   -0.004025     ...
# opp_current_all_stars           -0.085627   -0.009064     ...
# opp_lifetime_all_stars          -0.065196    0.024000     ...
# opp_player_salary                0.000754   -0.034367     ...
# is_weekend                       0.002794   -0.000602     ...
#
#                         Opp_Wins_last_10  Opp_Win_differential  Opp_Rank  \
# Attendance                     -0.010303              0.030410 -0.013288
# Gm#                            -0.007515              0.002374  0.032773
# Rank                            0.128135              0.117654 -0.150910
# GB                              0.097876              0.115094 -0.085874
# is_night                        0.033962              0.017088 -0.021323
# run_differential               -0.100918             -0.097967  0.094613
# Win_differential               -0.114752             -0.112375  0.111708
# Wins_last_10                   -0.259727             -0.120330  0.119026
# Mean_runs_last_10              -0.126571             -0.071116  0.089416
# batter_age                     -0.007826             -0.000386  0.013053
# current_all_stars              -0.081936             -0.050251  0.066347
# lifetime_all_stars             -0.042036             -0.038496  0.048797
# player_salary                  -0.032889             -0.043956  0.058102
# Opp_Wins_last_10                1.000000              0.449320 -0.435235
# Opp_Win_differential            0.449320              1.000000 -0.768633
# Opp_Rank                       -0.435235             -0.768633  1.000000
# Opp_GB                         -0.380151             -0.828274  0.712226
# Opp_Mean_runs_last_10           0.505106              0.213867 -0.242565
# opp_batter_age                  0.067332              0.168134 -0.173989
# opp_current_all_stars           0.261218              0.597491 -0.538306
# opp_lifetime_all_stars          0.197602              0.423192 -0.383564
# opp_player_salary               0.172151              0.394183 -0.395963
# is_weekend                     -0.015694             -0.011628  0.011834
#
#                           Opp_GB  Opp_Mean_runs_last_10  opp_batter_age  \
# Attendance             -0.016636              -0.041793        0.005322
# Gm#                     0.345866               0.033556       -0.007605
# Rank                   -0.099718               0.122056        0.011231
# GB                      0.046972               0.099352       -0.012238
# is_night                0.004852               0.015197        0.017921
# run_differential        0.108000              -0.089329        0.004860
# Win_differential        0.124021              -0.087142        0.001290
# Wins_last_10            0.108603              -0.157563       -0.002439
# Mean_runs_last_10       0.092009               0.047860       -0.016881
# batter_age             -0.003929              -0.022065       -0.004025
# current_all_stars       0.064077              -0.085994       -0.001176
# lifetime_all_stars      0.030084              -0.079267        0.031439
# player_salary           0.055616              -0.011820       -0.039481
# Opp_Wins_last_10       -0.380151               0.505106        0.067332
# Opp_Win_differential   -0.828274               0.213867        0.168134
# Opp_Rank                0.712226              -0.242565       -0.173989
# Opp_GB                  1.000000              -0.158748       -0.157569
# Opp_Mean_runs_last_10  -0.158748               1.000000        0.016458
# opp_batter_age         -0.157569               0.016458        1.000000
# opp_current_all_stars  -0.524676               0.149683        0.185851
# opp_lifetime_all_stars -0.384596               0.099488        0.408059
# opp_player_salary      -0.338778               0.132714        0.514585
# is_weekend              0.023562               0.001465        0.002332
#
#                         opp_current_all_stars  opp_lifetime_all_stars  \
# Attendance                           0.041622                0.067223
# Gm#                                  0.003723                0.002883
# Rank                                 0.074882                0.036496
# GB                                   0.063899                0.014794
# is_night                             0.013108                0.025859
# run_differential                    -0.068809               -0.030909
# Win_differential                    -0.061714               -0.028611
# Wins_last_10                        -0.063511               -0.016638
# Mean_runs_last_10                   -0.085627               -0.065196
# batter_age                          -0.009064                0.024000
# current_all_stars                   -0.048260               -0.016907
# lifetime_all_stars                  -0.015606                0.027413
# player_salary                       -0.054659               -0.086404
# Opp_Wins_last_10                     0.261218                0.197602
# Opp_Win_differential                 0.597491                0.423192
# Opp_Rank                            -0.538306               -0.383564
# Opp_GB                              -0.524676               -0.384596
# Opp_Mean_runs_last_10                0.149683                0.099488
# opp_batter_age                       0.185851                0.408059
# opp_current_all_stars                1.000000                0.499731
# opp_lifetime_all_stars               0.499731                1.000000
# opp_player_salary                    0.345151                0.592764
# is_weekend                           0.001302               -0.000174
#
#                         opp_player_salary  is_weekend
# Attendance                       0.053565    0.285766
# Gm#                             -0.006000    0.032328
# Rank                             0.028398   -0.004624
# GB                               0.024696    0.004760
# is_night                         0.020117   -0.267477
# run_differential                -0.017396    0.006604
# Win_differential                -0.024576    0.007219
# Wins_last_10                    -0.036168    0.009858
# Mean_runs_last_10                0.000754    0.002794
# batter_age                      -0.034367   -0.000602
# current_all_stars               -0.043598   -0.002198
# lifetime_all_stars              -0.078837   -0.004771
# player_salary                   -0.045419   -0.001224
# Opp_Wins_last_10                 0.172151   -0.015694
# Opp_Win_differential             0.394183   -0.011628
# Opp_Rank                        -0.395963    0.011834
# Opp_GB                          -0.338778    0.023562
# Opp_Mean_runs_last_10            0.132714    0.001465
# opp_batter_age                   0.514585    0.002332
# opp_current_all_stars            0.345151    0.001302
# opp_lifetime_all_stars           0.592764   -0.000174
# opp_player_salary                1.000000    0.003584
# is_weekend                       0.003584    1.000000
#
# [23 rows x 23 columns]

# %%
df_linreg_less_features = df_linreg.copy()

# %%
cols_for_linreg_less = ['Attendance',
 'Rank',
 'GB',
 'is_night',
 'run_differential',
 'Win_differential',
 'Wins_last_10',
 'batter_age',
 'current_all_stars',
 'lifetime_all_stars',
 'player_salary',
 'is_weekend']

# %%
df_linreg_less_features = df_linreg_less_features[cols_for_linreg_less]

# %%
df_linreg_less_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12318 entries, 6 to 24828
# Data columns (total 12 columns):
# Attendance            12318 non-null float64
# Rank                  12318 non-null int64
# GB                    12318 non-null float64
# is_night              12318 non-null int64
# run_differential      12318 non-null int64
# Win_differential      12318 non-null int64
# Wins_last_10          12318 non-null float64
# batter_age            12318 non-null float64
# current_all_stars     12318 non-null int64
# lifetime_all_stars    12318 non-null int64
# player_salary         12318 non-null int64
# is_weekend            12318 non-null int64
# dtypes: float64(4), int64(8)
# memory usage: 1.2 MB

# %%
with open('regression_data_v3_less_features.pickle', 'wb') as to_write:
    pickle.dump(df_linreg_less_features, to_write)
