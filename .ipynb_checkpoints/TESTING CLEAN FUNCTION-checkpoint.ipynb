# %%
import numpy as np
import pandas as pd
import data_clean_functions as dcf
import os
import pickle

# %%
with open('/Users/robertpagano/src/metis_project_luther/data/merged_data_2014_2018_final_uncleaned.pickle', "rb") as to_read:
    df = pickle.load(to_read)

# %%
df.head()
# Out:
#   Gm#       Date             Tm Location  Opp W/L  R RA Inn   ...       GB  \
# 0   1  201403310  boxscore  ATL        @  MIL   L  0  2       ...      1.0
# 1   2  201404010  boxscore  ATL        @  MIL   W  5  2       ...      1.0
# 2   3  201404020  boxscore  ATL        @  MIL   W  1  0       ...      0.5
# 3   4  201404040  boxscore  ATL        @  WSN   W  2  1       ...      0.5
# 4   5  201404050  boxscore  ATL        @  WSN   W  6  2       ...      0.5
#
#         Win       Loss       Save  Time D/N Attendance Streak Orig. Scheduled  \
# 0  Gallardo    Teheran  Rodriguez  2:45   D     45,691      -
# 1      Wood      Lohse    Kimbrel  2:34   N     21,503      +
# 2    Harang      Garza    Kimbrel  2:36   D     21,712     ++
# 3    Avilan   Clippard    Kimbrel  3:03   D     42,834    +++
# 4   Teheran  Strasburg             3:36   N     37,841   ++++
#
#   HomeGame
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['Gm#', 'Date', '', 'Tm', 'Location', 'Opp', 'W/L', 'R', 'RA', 'Inn',
#        'W-L', 'Rank', 'GB', 'Win', 'Loss', 'Save', 'Time', 'D/N', 'Attendance',
#        'Streak', 'Orig. Scheduled', 'HomeGame'],
#       dtype='object')

# %%
dcf.rename_columns(df)
df.columns
# Out:
# Index(['Gm#', 'Date', '', 'Tm', 'Location', 'Opp', 'W/L', 'runs_scored',
#        'runs_allowed', 'Inn', 'W-L', 'Rank', 'GB', 'Win', 'Loss', 'Save',
#        'Time', 'D/N', 'Attendance', 'Streak', 'Orig. Scheduled',
#        'home_or_away'],
#       dtype='object')

# %%
print(len(df.columns))
# Out:
# 22

# %%
dcf.filter_columns(df)
df.columns
# Out:
# Index(['Gm#', 'Date', '', 'Tm', 'Location', 'Opp', 'W/L', 'runs_scored',
#        'runs_allowed', 'W-L', 'Rank', 'GB', 'Time', 'D/N', 'Attendance',
#        'Streak', 'home_or_away'],
#       dtype='object')

# %%
print(len(df.columns))
# Out:
# 17

# %%
dcf.clean_GB_col(df)
# Out:
#        Gm#       Date             Tm Location  Opp   W/L runs_scored  \
# 0        1  201403310  boxscore  ATL        @  MIL     L           0
# 1        2  201404010  boxscore  ATL        @  MIL     W           5
# 2        3  201404020  boxscore  ATL        @  MIL     W           1
# 3        4  201404040  boxscore  ATL        @  WSN     W           2
# 4        5  201404050  boxscore  ATL        @  WSN     W           6
# 5        6  201404060  boxscore  ATL        @  WSN     L           1
# 6        7  201404080  boxscore  ATL           NYM     L           0
# 7        8  201404090  boxscore  ATL           NYM     W           4
# 8        9  201404100  boxscore  ATL           NYM     L           4
# 9       10  201404110  boxscore  ATL           WSN  W-wo           7
# 10      11  201404120  boxscore  ATL           WSN     W           6
# 11      12  201404130  boxscore  ATL           WSN     W          10
# 12      13  201404140  boxscore  ATL        @  PHI     W           9
# ...

# %% [markdown]
# Making sure 'GB' is float below:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24296 entries, 0 to 24295
# Data columns (total 17 columns):
# Gm#             24296 non-null object
# Date            24296 non-null object
#                 24296 non-null object
# Tm              24296 non-null object
# Location        24296 non-null object
# Opp             24296 non-null object
# W/L             24296 non-null object
# runs_scored     24296 non-null object
# runs_allowed    24296 non-null object
# W-L             24296 non-null object
# Rank            24296 non-null object
# GB              24296 non-null float64
# Time            24296 non-null object
# D/N             24296 non-null object
# Attendance      24296 non-null object
# Streak          24296 non-null object
# home_or_away    24296 non-null object
# dtypes: float64(1), object(16)
# memory usage: 3.3+ MB

# %%
dcf.split_win_loss(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24296 entries, 0 to 24295
# Data columns (total 19 columns):
# Gm#             24296 non-null object
# Date            24296 non-null object
#                 24296 non-null object
# Tm              24296 non-null object
# Location        24296 non-null object
# Opp             24296 non-null object
# W/L             24296 non-null object
# runs_scored     24296 non-null object
# runs_allowed    24296 non-null object
# W-L             24296 non-null object
# Rank            24296 non-null object
# GB              24296 non-null float64
# Time            24296 non-null object
# D/N             24296 non-null object
# Attendance      24296 non-null object
# Streak          24296 non-null object
# home_or_away    24296 non-null object
# Total_wins      24296 non-null int64
# Total_losses    24296 non-null int64
# dtypes: float64(1), int64(2), object(16)
# memory usage: 3.7+ MB

# %%
dcf.calc_win_differential(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24296 entries, 0 to 24295
# Data columns (total 20 columns):
# Gm#                 24296 non-null object
# Date                24296 non-null object
#                     24296 non-null object
# Tm                  24296 non-null object
# Location            24296 non-null object
# Opp                 24296 non-null object
# W/L                 24296 non-null object
# runs_scored         24296 non-null object
# runs_allowed        24296 non-null object
# W-L                 24296 non-null object
# Rank                24296 non-null object
# GB                  24296 non-null float64
# Time                24296 non-null object
# D/N                 24296 non-null object
# Attendance          24296 non-null object
# Streak              24296 non-null object
# home_or_away        24296 non-null object
# Total_wins          24296 non-null int64
# Total_losses        24296 non-null int64
# Win_differential    24296 non-null int64
# ...

# %%
dcf.count_cum_wins(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24296 entries, 0 to 24295
# Data columns (total 22 columns):
# Gm#                 24296 non-null object
# Date                24296 non-null object
#                     24296 non-null object
# Tm                  24296 non-null object
# Location            24296 non-null object
# Opp                 24296 non-null object
# W/L                 24296 non-null object
# runs_scored         24296 non-null object
# runs_allowed        24296 non-null object
# W-L                 24296 non-null object
# Rank                24296 non-null object
# GB                  24296 non-null float64
# Time                24296 non-null object
# D/N                 24296 non-null object
# Attendance          24296 non-null object
# Streak              24296 non-null object
# home_or_away        24296 non-null object
# Total_wins          24296 non-null int64
# Total_losses        24296 non-null int64
# Win_differential    24296 non-null int64
# ...

# %%
dcf.calc_mean_runs_last_10(df)
df.sample(5)
# Out:
#       Gm#       Date             Tm Location  Opp W/L runs_scored  \
# 7502   53  201506040  boxscore  MIN        @  BOS   W           8
# 18792   7  201704090  boxscore  TBR           TOR   W           7
# 15079  20  201704260  boxscore  BOS           NYY   L           1
# 12657  28  201605070  boxscore  NYY           BOS   W           8
# 6405   89  201507170  boxscore  DET           BAL   W           7
#
#       runs_allowed    W-L        ...         D/N  Attendance Streak  \
# 7502             4  32-21        ...           D      33,615     ++
# 18792            2    5-2        ...           D      15,341    +++
# 15079            3   11-9        ...           N      32,072      -
# 12657            2  11-17        ...           D      47,822     ++
# 6405             3  45-44        ...           N      36,378      +
#
#       home_or_away Total_wins Total_losses Win_differential  win_value  \
# 7502         False         32           21               11          1
# ...

# %%
dcf.calc_run_diff(df)
df.tail(5)
# Out:
#        Gm#       Date             Tm Location  Opp W/L  runs_scored  \
# 24291  158  201809250  boxscore  WSN           MIA   W            9
# 24292  159  201809260  boxscore  WSN           MIA   W            9
# 24293  160  201809280  boxscore  WSN        @  COL   L            2
# 24294  161  201809290  boxscore  WSN        @  COL   W           12
# 24295  162  201809300  boxscore  WSN        @  COL   L            0
#
#        runs_allowed    W-L        ...        home_or_away  Total_wins  \
# 24291             4  80-78        ...                True          80
# 24292             3  81-78        ...                True          81
# 24293             5  81-79        ...               False          81
# 24294             2  82-79        ...               False          82
# 24295            12  82-80        ...               False          82
#
#       Total_losses Win_differential win_value Wins_last_10 Mean_runs_last_10  \
# ...

# %%
with open('merged_data_initial_clean.pickle', 'wb') as to_write:
    pickle.dump(df, to_write)

# %%
df.head(5)
# Out:
#   Gm#       Date             Tm Location  Opp W/L  runs_scored  runs_allowed  \
# 0   1  201403310  boxscore  ATL        @  MIL   L            0             2
# 1   2  201404010  boxscore  ATL        @  MIL   W            5             2
# 2   3  201404020  boxscore  ATL        @  MIL   W            1             0
# 3   4  201404040  boxscore  ATL        @  WSN   W            2             1
# 4   5  201404050  boxscore  ATL        @  WSN   W            6             2
#
#    W-L        ...        home_or_away  Total_wins Total_losses  \
# 0  0-1        ...               False           0            1
# 1  1-1        ...               False           1            1
# 2  2-1        ...               False           2            1
# 3  3-1        ...               False           3            1
# 4  4-1        ...               False           4            1
#
#   Win_differential win_value Wins_last_10 Mean_runs_last_10  cum_runs_scored  \
# ...

# %%
with open('rays_df_2017.pickle', 'wb') as to_write:
    pickle.dump(rays_df_2017, to_write)
