# %%
import pickle
import pandas as pd
import numpy as np

# %%
with open('rays_df_2017.pickle','rb') as read_file:
    new_df = pickle.load(read_file)
    
new_df.head(5)
# Out:
#    Attendance  Gm#             Date   Tm home_or_away  Opp W/L  runs_scored  \
# 0     31042.0    1     Sunday Apr 2  TBR         Home  NYY   W            7
# 1     19366.0    2    Tuesday Apr 4  TBR         Home  NYY   L            0
# 2     12737.0    3  Wednesday Apr 5  TBR         Home  NYY   W            4
# 3     12678.0    4   Thursday Apr 6  TBR         Home  TOR   L            2
# 4     12842.0    5     Friday Apr 7  TBR         Home  TOR   W           10
#
#    runs_allowed  W-L        ...         Streak  Total_wins Total_losses  \
# 0             3  1-0        ...              +           1            0
# 1             5  1-1        ...              -           1            1
# 2             1  2-1        ...              +           2            1
# 3             5  2-2        ...              -           2            2
# 4             8  3-2        ...              +           3            2
#
#   Win_differential win_value  Wins_last_10  Mean_runs_last_10  \
# ...
