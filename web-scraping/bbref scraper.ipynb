# %%
import pandas, numpy
import requests, bs4
import re, os
import bbref_scrape as bbrs

# %%
bbrs.findTables('https://www.baseball-reference.com/teams/KCR/2016-schedule-scores.shtml')
# Out:
# ['results', 'table', 'team_schedule']

# %%
bbrs.pullTable('https://www.baseball-reference.com/teams/KCR/2016-schedule-scores.shtml', 'team_schedule')
# Out:
#      Gm#               Date             Tm     Opp   W/L   R  RA Inn  \
# 0      1      Sunday, Apr 3  boxscore  KCR     NYM     W   4   3
# 1      2     Tuesday, Apr 5  boxscore  KCR     NYM     L   0   2
# 2      3      Friday, Apr 8  boxscore  KCR     MIN     W   4   3
# 3      4    Saturday, Apr 9  boxscore  KCR     MIN     W   7   0
# 4      5     Sunday, Apr 10  boxscore  KCR     MIN  W-wo   4   3  10
# 5      6     Monday, Apr 11  boxscore  KCR  @  HOU     L   2   8
# 6      7    Tuesday, Apr 12  boxscore  KCR  @  HOU     W   3   2
# 7      8  Wednesday, Apr 13  boxscore  KCR  @  HOU     W   4   2
# 8      9   Thursday, Apr 14  boxscore  KCR  @  HOU     W   6   2
# 9     10     Friday, Apr 15  boxscore  KCR  @  OAK     W   4   2
# 10    11   Saturday, Apr 16  boxscore  KCR  @  OAK     L   3   5
# 11    12     Sunday, Apr 17  boxscore  KCR  @  OAK     L   2   3
# 12    13    Tuesday, Apr 19  boxscore  KCR     DET     W   8   6
# ...

# %%
bbrs.pullGameData('KCR', 2015).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 22 columns):
# Gm#                162 non-null object
# Date               162 non-null object
#                    162 non-null object
# Tm                 162 non-null object
# Location           162 non-null object
# Opp                162 non-null object
# W/L                162 non-null object
# R                  162 non-null object
# RA                 162 non-null object
# Inn                162 non-null object
# W-L                162 non-null object
# Rank               162 non-null object
# GB                 162 non-null object
# Win                162 non-null object
# Loss               162 non-null object
# Save               162 non-null object
# Time               162 non-null object
# D/N                162 non-null object
# Attendance         162 non-null object
# Streak             162 non-null object
# Orig. Scheduled    162 non-null object
# ...

# %%
import argparse
from bbref_scrape import pullGameData
import gameData
# Out:
# usage: ipykernel_launcher.py [-h] [--year YEAR] [--datdir DATDIR]
# ipykernel_launcher.py: error: unrecognized arguments: -f /Users/robertpagano/Library/Jupyter/runtime/kernel-a11a8932-f150-4c24-bdc5-46deca4b362b.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3275: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
gameData.yearData(2017, 'testfiles')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-01db78d537b0> in <module>
# ----> 1 gameData.yearData(2017, 'testfiles')
#
# NameError: name 'gameData' is not defined
